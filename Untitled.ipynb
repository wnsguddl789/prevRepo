# %%
import os
import json
import matplotlib.pyplot as plt
from krwordrank.word import KRWordRank
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pprint as pp
import pandas as pd

# %%
def search(dirname):  # 디렉토리 속 파일 경로 리스트 가져오기 ex : ./Result/file.txt
    file_name_list = list()
    filenames = os.listdir(dirname)
    for filename in filenames:
        full_filename = os.path.join(dirname, filename)
        file_name_list.append(full_filename)
    return file_name_list

# %%
def file_read(file_name_list):  # json 으로 해당 경로 파일 가져오기
    data = list()
    for file_path in file_name_list:
        with open(file_path, 'r') as file_point:
            data.append(json.load(file_point))
    return data

# %%
wordcloud = WordCloud(
    font_path = './NanumGothic.ttf',
    width = 1200,
    height = 1200,
    background_color="white"
)

# %%
def __array__(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return self.to_array()
 
def to_array(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return np.array(self.to_image())

# %%
with open("list/negative_list_free.json",'r',encoding='utf-8-sig') as st_json:
    negative_list_free = json.load(st_json)
with open("list/positive_list_free.json",'r',encoding='utf-8-sig') as st_json:
    positive_list_free = json.load(st_json)
with open("list/negative_list_depressed.json",'r',encoding='utf-8-sig') as st_json:
    negative_list_depressed = json.load(st_json)
with open("list/positive_list_depressed.json",'r',encoding='utf-8-sig') as st_json:
    positive_list_depressed = json.load(st_json)

# %%
wordcloud.generate(str(positive_list_free))
fig = plt.figure(figsize=(20, 10))
array = wordcloud.to_array()
plt.imshow(array, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.generate(str(negative_list_free))
fig = plt.figure(figsize=(20, 10))
array = wordcloud.to_array()
plt.imshow(array, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.generate(str(positive_list_depressed))
fig = plt.figure(figsize=(20, 10))
array = wordcloud.to_array()
plt.imshow(array, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.generate(str(negative_list_depressed))
fig = plt.figure(figsize=(20, 10))
array_4 = wordcloud.to_array()
plt.imshow(array_4, interpolation="bilinear")
plt.axis("off")
plt.show()
